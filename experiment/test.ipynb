# %%
from sharding_methods.OurMethod import our_split
import pandas as pd
import numpy as np



splits = our_split(df, arr)
# Out:
# [('LT', 9.813307517998973), ('GE', 3.4266157179722123), ('GE', 6.846439487367405), ('GT', 7.167235898137441), ('GE', 0.11972176096080256), ('LE', 3.9111489120887266), ('GT', 9.0685441561664), ('LT', 1.9242017902389175), ('LE', 8.98642035140364), ('LT', 9.481490275626072), ('LE', 1.4439519685606483), ('LT', 8.100452992654278), ('GE', 6.106006366684573), ('GT', 1.867270840327222), ('LE', 3.056849767887072), ('GT', 3.1098907365413178), ('LE', 9.56834653370154), ('GE', 0.8070222081791678), ('LT', 0.3270076366379182), ('LE', 8.519793639162165), ('GE', 7.957001191781546), ('LT', 4.705657976494718), ('GE', 0.3501067917526679), ('LT', 6.1140610889152125), ('LE', 1.3932714964195947), ('GT', 5.6624740104690785), ('LT', 1.948459421367531), ('GT', 1.9327590896750146), ('LT', 5.764649311056395), ('GT', 5.1808555726933925), ('LE', 6.223320927473472), ('GE', 3.822221487589983), ('LE', 7.607239735036416), ('GT', 0.5440487360224711), ('GT', 1.0985193109902869), ('LT', 3.903775965364117), ('LE', 6.168
# ...
